# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import random
import matplotlib.pyplot as plt
from tensorflow.keras import backend as K
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, concatenate, Conv2DTranspose, BatchNormalization, Activation, Dropout
from tensorflow.keras.optimizers import Adadelta, Nadam ,Adam
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.utils import  plot_model ,Sequence
from tensorflow.keras.callbacks import TensorBoard, ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.preprocessing.image import load_img,img_to_array
import tensorflow as tf
from tensorflow.python.keras.losses import binary_crossentropy
from scipy.ndimage import morphology as mp
from PIL import Image
# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory

import os
from glob import glob  # for getting list paths of image and labels
from random import choice,sample
from matplotlib import pyplot as plt
import cv2 # saving and loading images

# %%
path = '/content/drive/MyDrive/COL828_Data_for_Assignment_3/train/annotations/'

for f in os.listdir(path):
    img = Image.open(os.path.join(path,f))
    img = img.convert('RGB')
    r,g,b = img.split()
    r = r.point(lambda i:i*32)
    out = Image.merge('RGB',(r,g,b))
    out.save('/content/drive/MyDrive/COL828_Data_for_Assignment_3/train/pixeled_annotations_train/{}'.format(f))

# %%
path = '/content/drive/MyDrive/COL828_Data_for_Assignment_3/val/annotations/'

for f in os.listdir(path):
    img = Image.open(os.path.join(path,f))
    img = img.convert('RGB')
    r,g,b = img.split()
    r = r.point(lambda i:i*32)
    out = Image.merge('RGB',(r,g,b))
    out.save('/content/drive/MyDrive/COL828_Data_for_Assignment_3/val/pixeled_annotations_valid/{}'.format(f))

# %%
train_img_dir = '/content/drive/MyDrive/COL828_Data_for_Assignment_3/train/images/' 
train_mask_dir = '/content/drive/MyDrive/COL828_Data_for_Assignment_3/train/pixeled_annotations_train/'
train_imgs = os.listdir(train_img_dir)# if you have an error take a look here ...
train_masks = os.listdir(train_mask_dir)
train_imgs= sorted([ i for i in train_imgs ])
train_masks= sorted([ i for i in train_masks ])
print(len(train_imgs))
print(len(train_masks))
# Out:
# 1335
# 1335

# %%
print(train_imgs[:])
print(train_masks[:])
# Out:
# ['seq_10_frame000.png', 'seq_10_frame001.png', 'seq_10_frame002.png', 'seq_10_frame003.png', 'seq_10_frame004.png', 'seq_10_frame005.png', 'seq_10_frame006.png', 'seq_10_frame007.png', 'seq_10_frame008.png', 'seq_10_frame009.png', 'seq_10_frame010.png', 'seq_10_frame011.png', 'seq_10_frame012.png', 'seq_10_frame013.png', 'seq_10_frame014.png', 'seq_10_frame015.png', 'seq_10_frame016.png', 'seq_10_frame017.png', 'seq_10_frame018.png', 'seq_10_frame019.png', 'seq_10_frame020.png', 'seq_10_frame021.png', 'seq_10_frame023.png', 'seq_10_frame024.png', 'seq_10_frame025.png', 'seq_10_frame026.png', 'seq_10_frame027.png', 'seq_10_frame028.png', 'seq_10_frame029.png', 'seq_10_frame030.png', 'seq_10_frame031.png', 'seq_10_frame032.png', 'seq_10_frame033.png', 'seq_10_frame034.png', 'seq_10_frame035.png', 'seq_10_frame036.png', 'seq_10_frame037.png', 'seq_10_frame038.png', 'seq_10_frame039.png', 'seq_10_frame040.png', 'seq_10_frame041.png', 'seq_10_frame042.png', 'seq_10_frame043.png', 'seq_10_frame044.png', 'seq_10_frame045.png', 'seq_10_frame046.png', 'seq_10_frame047.png', 'seq_10_frame048.png', 'seq_10_frame049.png', 'seq_10_frame050.png', 'seq_10_frame051.png', 'seq_10_frame052.png', 'seq_10_frame053.png', 'seq_10_frame054.png', 'seq_10_frame055.png', 'seq_10_frame056.png', 'seq_10_frame057.png', 'seq_10_frame058.png', 'seq_10_frame059.png', 'seq_10_frame060.png', 'seq_10_frame061.png', 'seq_10_frame062.png', 'seq_10_frame063.png', 'seq_10_frame064.png', 'seq_10_frame065.png', 'seq_10_frame066.png', 'seq_10_frame067.png', 'seq_10_frame068.png', 'seq_10_frame069.png', 'seq_10_frame070.png', 'seq_10_frame071.png', 'seq_10_frame072.png', 'seq_10_frame073.png', 'seq_10_frame074.png', 'seq_10_
seq_11_frame002.png', 'seq_11_frame003.png', 'seq_11_frame004.png', 'seq_11_frame005.png', 'seq_11_frame006.png', 'seq_11_frame007.png', 'seq_11_frame008.png', 'seq_11_frame009.png', 'seq_11_frame010.png', 'seq_11_frame011.png', 'seq_11_frame012.png', 'seq_11_frame013.png', 'seq_11_frame014.png', 'seq_11_frame015.png', 'seq_11_frame016.png', 'seq_11_frame017.png', 'seq_11_frame018.png', 'seq_11_frame019.png', 'seq_11_frame020.png', 'seq_11_frame021.png', 'seq_11_frame022.png', 'seq_11_frame023.png', 'seq_11_frame024.png', 'seq_11_frame025.png ...

# %%
from sklearn.model_selection import train_test_split

val_img_dir =  train_img_dir
val_mask_dir = train_mask_dir


train_imgs,val_imgs,train_masks,val_masks =  train_test_split(train_imgs, train_masks, test_size=0.13, random_state=42)


print(len(train_masks))
print(len(val_masks))
# Out:
# 1161
# 174

# %%
class DataGenerator(Sequence):
    'Generates data for Keras'
    
    def __init__(self, images,image_dir,labels,label_dir ,batch_size=16, dim=(224,224,3) ,shuffle=True):
        'Initialization'
        self.dim = dim
        self.images = images
        self.image_dir = image_dir
        self.labels = labels
        self.label_dir = label_dir
        self.batch_size = batch_size
        self.shuffle = shuffle
        self.on_epoch_end()

    def __len__(self):
        'Denotes the number of batches per epoch'
        return int(np.floor(len(self.images) / self.batch_size))

    def __getitem__(self, index):
        'Generate one batch of data'
        # Generate indexes of the batch
        indexes = self.indexes[index*self.batch_size:(index+1)*self.batch_size]

        # Find list of IDs
        list_IDs_temp = [k for k in indexes]

        # Generate data
        X, y = self.__data_generation(list_IDs_temp)

        return X, y

    def on_epoch_end(self):
        'Updates indexes after each epoch'
        self.indexes = np.arange(len(self.images))
        if self.shuffle == True:
            np.random.shuffle(self.indexes)

    def __data_generation(self, list_IDs_temp):
        'Generates data containing batch_size samples' # X : (n_samples, *dim, n_channels)
        # Initialization
        batch_imgs = list()
        batch_labels = list()

        # Generate data
        for i in list_IDs_temp:
#             degree=np.random.random() * 360
            # Store sample
            img = load_img(self.image_dir + self.images[i] ,target_size=self.dim)
            img = img_to_array(img)/255.
#             img = ndimage.rotate(img, degree)
#             print(img)
            batch_imgs.append(img)
           # Store class
            label = load_img(self.label_dir + self.labels[i] ,target_size=self.dim)
            label = img_to_array(label)[:,:,0]
            label = label != 0
            label = mp.binary_erosion(mp.binary_erosion(label))
            label = mp.binary_dilation(mp.binary_dilation(mp.binary_dilation(label)))
            label = np.expand_dims((label)*1 , axis=2)
            batch_labels.append(label)
            
        return np.array(batch_imgs,dtype = np.float32 ) ,np.array(batch_labels , dtype = np.float32 )

# %%
train_generator = DataGenerator(train_imgs,train_img_dir,train_masks,train_mask_dir,batch_size=36, dim=(224,224,3) ,shuffle=True)
train_steps = train_generator.__len__()
train_steps
# Out:
# 32

# %%
X,y = train_generator.__getitem__(2)
t = 12

plt.figure(figsize=(8,8))
plt.subplot(121)
plt.imshow(X[t])
plt.subplot(122)
plt.imshow(np.reshape(y[t],(224,224)))

# %%
val_generator = DataGenerator(val_imgs,val_img_dir,val_masks,val_mask_dir,batch_size=36, dim=(224,224,3) ,shuffle=True)
val_steps = val_generator.__len__()
val_steps
# Out:
# 4

# %%
def conv_block(tensor, nfilters, size=3, padding='same', initializer="he_normal"):
    x = Conv2D(filters=nfilters, kernel_size=(size, size), padding=padding, kernel_initializer=initializer)(tensor)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)
    x = Conv2D(filters=nfilters, kernel_size=(size, size), padding=padding, kernel_initializer=initializer)(x)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)
    return x


def deconv_block(tensor, residual, nfilters, size=3, padding='same', strides=(2, 2)):
    y = Conv2DTranspose(nfilters, kernel_size=(size, size), strides=strides, padding=padding)(tensor)
    y = concatenate([y, residual], axis=3)
    y = conv_block(y, nfilters)
    return y


def Unet(h, w, filters):
# down
    input_layer = Input(shape=(h, w, 3), name='image_input')
    conv1 = conv_block(input_layer, nfilters=filters)
    conv1_out = MaxPooling2D(pool_size=(2, 2))(conv1)
    conv2 = conv_block(conv1_out, nfilters=filters*2)
    conv2_out = MaxPooling2D(pool_size=(2, 2))(conv2)
    conv3 = conv_block(conv2_out, nfilters=filters*4)
    conv3_out = MaxPooling2D(pool_size=(2, 2))(conv3)
    conv4 = conv_block(conv3_out, nfilters=filters*8)
    conv4_out = MaxPooling2D(pool_size=(2, 2))(conv4)
    conv4_out = Dropout(0.5)(conv4_out)
    conv5 = conv_block(conv4_out, nfilters=filters*16)
    conv5 = Dropout(0.5)(conv5)
# up
    deconv6 = deconv_block(conv5, residual=conv4, nfilters=filters*8)
    deconv6 = Dropout(0.5)(deconv6)
    deconv7 = deconv_block(deconv6, residual=conv3, nfilters=filters*4)
    deconv7 = Dropout(0.5)(deconv7) 
    deconv8 = deconv_block(deconv7, residual=conv2, nfilters=filters*2)
    deconv9 = deconv_block(deconv8, residual=conv1, nfilters=filters)
    output_layer = Conv2D(filters=1, kernel_size=(1, 1), activation='sigmoid')(deconv9)
    # using sigmoid activation for binary classification
    model = Model(inputs=input_layer, outputs=output_layer, name='Unet')
    return model

# %%
model = Unet(224 , 224 , 64)
model.summary()
# Out:
# Model: "Unet"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  image_input (InputLayer)       [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv2d_19 (Conv2D)             (None, 224, 224, 64  1792        ['image_input[0][0]']
#                                 )
#
#  batch_normalization_18 (BatchN  (None, 224, 224, 64  256        ['conv2d_19[0][0]']
#  ormalization)                  )
#
#  activation_18 (Activation)     (None, 224, 224, 64  0           ['batch_normalization_18[0][0]']
#                                 )
#
#  conv2d_20 (Conv2D)             (None, 224, 224, 64  36928       ['activation_18[0][0]']
#                                 )
#
#  batch_normalization_19 (BatchN  (None, 224, 224, 64  256        ['conv2d_20[0][0]']
#  ormalization)                  )
#
#  activation_19 (Activation)     (None, 224, 224, 64  0           ['batch_normalization_19[0][0]']
#                                 )
#
#  max_pooling2d_4 (MaxPooling2D)  (None, 112, 112, 64  0          ['activation_19[0][0]']
#                                 )
#
#  conv2d_21 (Conv2D)             (None, 112, 112, 12  73856       ['max_pooling2d_4[0][0]']
#                                 8)
#
#  batch_normalization_20 (BatchN  (None, 112, 112, 12  512        ['conv2d_21[0][0]']
#  ormalization)                  8)
#
#  activation_20 (Activation)     (None, 112, 112, 12  0           ['batch_normalization_20[0][0]']
#                                 8)
#
#  conv2d_22 (Conv2D)             (None, 112, 112, 12  147584      ['activation_20[0][0]']
#                                 8)
#
#  batch_normalization_21 (BatchN  (None, 112, 112, 12  512        ['conv2d_22[0][0]']
#  ormalization)                  8)
#
#  activation_21 (Activation)     (None, 112, 112, 12  0           ['batch_normalization_21[0][0]']
#                                 8)
#
#  max_pooling2d_5 (MaxPooling2D)  (None, 56, 56, 128)  0          ['activation_21[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 56, 56, 256)  295168      ['max_pooling2d_5[0][0]']
#
#  batch_normalization_22 (BatchN  (None, 56, 56, 256)  1024       ['conv2d_23[0][0]']
#  ormalization)
#
#  activation_22 (Activation)     (None, 56, 56, 256)  0           ['batch_normalization_22[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 56, 56, 256)  590080      ['activation_22[0][0]']
#
#  batch_normalization_23 (BatchN  (None, 56, 56, 256)  1024       ['conv2d_24[0][0]']
#  ormalization)
#
#  activation_23 (Activation)     (None, 56, 56, 256)  0           ['batch_normalization_23[0][0]']
#
#  max_pooling2d_6 (MaxPooling2D)  (None, 28, 28, 256)  0          ['activation_23[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 28, 28, 512)  1180160     ['max_pooling2d_6[0][0]']
#
#  batch_normalization_24 (BatchN  (None, 28, 28, 512)  2048       ['conv2d_25[0][0]']
#  ormalization)
#
#  activation_24 (Activation)     (None, 28, 28, 512)  0           ['batch_normalization_24[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 28, 28, 512)  2359808     ['activation_24[0][0]']
#
#  batch_normalization_25 (BatchN  (None, 28, 28, 512)  2048       ['conv2d_26[0][0]']
#  ormalization)
#
#  activation_25 (Activation)     (None, 28, 28, 512)  0           ['batch_normalization_25[0][0]']
#
#  max_pooling2d_7 (MaxPooling2D)  (None, 14, 14, 512)  0          ['activation_25[0][0]']
#
#  dropout_4 (Dropout)            (None, 14, 14, 512)  0           ['max_pooling2d_7[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 14, 14, 1024  4719616     ['dropout_4[0][0]']
#                                 )
#
#  batch_normalization_26 (BatchN  (None, 14, 14, 1024  4096       ['conv2d_27[0][0]']
#  ormalization)                  )
#
#  activation_26 (Activation)     (None, 14, 14, 1024  0           ['batch_normalization_26[0][0]']
#                                 )
#
#  conv2d_28 (Conv2D)             (None, 14, 14, 1024  9438208     ['activation_26[0][0]']
#                                 )
#
#  batch_normalization_27 (BatchN  (None, 14, 14, 1024  4096       ['conv2d_28[0][0]']
#  ormalization)                  )
#
#  activation_27 (Activation)     (None, 14, 14, 1024  0           ['batch_normalization_27[0][0]']
#                                 )
#
#  dropout_5 (Dropout)            (None, 14, 14, 1024  0           ['activation_27[0][0]']
#                                 )
#
#  conv2d_transpose_4 (Conv2DTran  (None, 28, 28, 512)  4719104    ['dropout_5[0][0]']
#  spose)
#
#  concatenate_4 (Concatenate)    (None, 28, 28, 1024  0           ['conv2d_transpose_4[0][0]',
#                                 )                                 'activation_25[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 28, 28, 512)  4719104     ['concatenate_4[0][0]']
#
#  batch_normalization_28 (BatchN  (None, 28, 28, 512)  2048       ['conv2d_29[0][0]']
#  ormalization)
#
#  activation_28 (Activation)     (None, 28, 28, 512)  0           ['batch_normalization_28[0][0]']
#
#  conv2d_30 (Conv2D)             (None, 28, 28, 512)  2359808     ['activation_28[0][0]']
#
#  batch_normalization_29 (BatchN  (None, 28, 28, 512)  2048       ['conv2d_30[0][0]']
#  ormalization)
#
#  activation_29 (Activation)     (None, 28, 28, 512)  0           ['batch_normalization_29[0][0]']
#
#  dropout_6 (Dropout)            (None, 28, 28, 512)  0           ['activation_29[0][0]']
#
#  conv2d_transpose_5 (Conv2DTran  (None, 56, 56, 256)  1179904    ['dropout_6[0][0]']
#  spose)
#
#  concatenate_5 (Concatenate)    (None, 56, 56, 512)  0           ['conv2d_transpose_5[0][0]',
#                                                                   'activation_23[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 56, 56, 256)  1179904     ['concatenate_5[0][0]']
#
#  batch_normalization_30 (BatchN  (None, 56, 56, 256)  1024       ['conv2d_31[0][0]']
#  ormalization)
#
#  activation_30 (Activation)     (None, 56, 56, 256)  0           ['batch_normalization_30[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 56, 56, 256)  590080      ['activation_30[0][0]']
#
#  batch_normalization_31 (BatchN  (None, 56, 56, 256)  1024       ['conv2d_32[0][0]']
#  ormalization)
#
#  activation_31 (Activation)     (None, 56, 56, 256)  0           ['batch_normalization_31[0][0]']
#
#  dropout_7 (Dropout)            (None, 56, 56, 256)  0           ['activation_31[0][0]']
#
#  conv2d_transpose_6 (Conv2DTran  (None, 112, 112, 12  295040     ['dropout_7[0][0]']
#  spose)                         8)
#
#  concatenate_6 (Concatenate)    (None, 112, 112, 25  0           ['conv2d_transpose_6[0][0]',
#                                 6)                                'activation_21[0][0]']
#
#  conv2d_33 (Conv2D)             (None, 112, 112, 12  295040      ['concatenate_6[0][0]']
#                                 8)
#
#  batch_normalization_32 (BatchN  (None, 112, 112, 12  512        ['conv2d_33[0][0]']
#  ormalization)                  8)
#
#  activation_32 (Activation)     (None, 112, 112, 12  0           ['batch_normalization_32[0][0]']
#                                 8)
#
#  conv2d_34 (Conv2D)             (None, 112, 112, 12  147584      ['activation_32[0][0]']
#                                 8)
#
#  batch_normalization_33 (BatchN  (None, 112, 112, 12  512        ['conv2d_34[0][0]']
#  ormalization)                  8)
#
#  activation_33 (Activation)     (None, 112, 112, 12  0           ['batch_normalization_33[0][0]']
#                                 8)
#
#  conv2d_transpose_7 (Conv2DTran  (None, 224, 224, 64  73792      ['activation_33[0][0]']
#  spose)                         )
#
#  concatenate_7 (Concatenate)    (None, 224, 224, 12  0           ['conv2d_transpose_7[0][0]',
#                                 8)                                'activation_19[0][0]']
#
#  conv2d_35 (Conv2D)             (None, 224, 224, 64  73792       ['concatenate_7[0][0]']
#                                 )
#
#  batch_normalization_34 (BatchN  (None, 224, 224, 64  256        ['conv2d_35[0][0]']
#  ormalization)                  )
#
#  activation_34 (Activation)     (None, 224, 224, 64  0           ['batch_normalization_34[0][0]']
#                                 )
#
#  conv2d_36 (Conv2D)             (None, 224, 224, 64  36928       ['activation_34[0][0]']
#                                 )
#
#  batch_normalization_35 (BatchN  (None, 224, 224, 64  256        ['conv2d_36[0][0]']
#  ormalization)                  )
#
#  activation_35 (Activation)     (None, 224, 224, 64  0           ['batch_normalization_35[0][0]']
#                                 )
#
#  conv2d_37 (Conv2D)             (None, 224, 224, 1)  65          ['activation_35[0][0]']
#
# ==================================================================================================
# Total params: 34,536,897
# Trainable params: 34,525,121
# Non-trainable params: 11,776
# __________________________________________________________________________________________________

# %%
def jaccard_distance_loss(y_true, y_pred,smooth = 100):
    intersection = K.sum(K.abs(y_true * y_pred), axis=-1)
    sum_ = K.sum(K.abs(y_true) + K.abs(y_pred), axis=-1)
    jac = (intersection + smooth) / (sum_ - intersection + smooth)
    return (1 - jac) * smooth

def dice_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + K.epsilon()) / (K.sum(y_true_f) + K.sum(y_pred_f) + K.epsilon())

# %%
model.compile(optimizer='adam', loss=jaccard_distance_loss ,metrics = [dice_coef, 'accuracy'])
mc = ModelCheckpoint(mode='max', filepath='top-weights.h5', monitor='val_dice_coef',save_best_only='True', save_weights_only='True', verbose=1)
es = EarlyStopping(mode='max', monitor='val_dice_coef', patience=3, verbose=1)
callbacks = []
model.metrics_names
# Out:
# []

# %%
results = model.fit_generator(train_generator, steps_per_epoch=train_steps,epochs=40,callbacks=callbacks,validation_data=val_generator,validation_steps=val_steps)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   """Entry point for launching an IPython kernel.
# Epoch 1/40
# 32/32 [==============================] - 122s 3s/step - loss: 0.1921 - dice_coef: 0.5619 - accuracy: 0.8666 - val_loss: 0.8196 - val_dice_coef: 0.2782 - val_accuracy: 0.1737
# Epoch 2/40
# 32/32 [==============================] - 84s 3s/step - loss: 0.0938 - dice_coef: 0.7329 - accuracy: 0.9343 - val_loss: 0.8055 - val_dice_coef: 0.2911 - val_accuracy: 0.1877
# Epoch 3/40
# 32/32 [==============================] - 80s 2s/step - loss: 0.0684 - dice_coef: 0.7961 - accuracy: 0.9474 - val_loss: 0.4472 - val_dice_coef: 0.2138 - val_accuracy: 0.5895
# Epoch 4/40
# 32/32 [==============================] - 82s 3s/step - loss: 0.0509 - dice_coef: 0.8473 - accuracy: 0.9592 - val_loss: 0.2729 - val_dice_coef: 0.2428 - val_accuracy: 0.7796
# Epoch 5/40
# 32/32 [==============================] - 80s 2s/step - loss: 0.0467 - dice_coef: 0.8576 - accuracy: 0.9604 - val_loss: 0.2238 - val_dice_coef: 0.1458 - val_accuracy: 0.7828
# Epoch 6/40
# 32/32 [==============================] - 79s 2s/step - loss: 0.0420 - dice_coef: 0.8716 - accuracy: 0.9631 - val_loss: 0.1592 - val_dice_coef: 0.4765 - val_accuracy: 0.8467
# Epoch 7/40
# 32/32 [==============================] - 84s 3s/step - loss: 0.0367 - dice_coef: 0.8877 - accuracy: 0.9673 - val_loss: 0.1541 - val_dice_coef: 0.2839 - val_accuracy: 0.8497
# Epoch 8/40
# 32/32 [==============================] - 79s 2s/step - loss: 0.0311 - dice_coef: 0.9048 - accuracy: 0.9720 - val_loss: 0.1256 - val_dice_coef: 0.4933 - val_accuracy: 0.8778
# Epoch 9/40
# 32/32 [==============================] - 81s 2s/step - loss: 0.0291 - dice_coef: 0.9115 - accuracy: 0.9735 - val_loss: 0.1165 - val_dice_coef: 0.6469 - val_accuracy: 0.8868
# Epoch 10/40
# 32/32 [==============================] - 79s 2s/step - loss: 0.0295 - dice_coef: 0.9094 - accuracy: 0.9726 - val_loss: 0.1081 - val_dice_coef: 0.6165 - val_accuracy: 0.8936
# Epoch 11/40
# 32/32 [==============================] - 80s 2s/step - loss: 0.0262 - dice_coef: 0.9203 - accuracy: 0.9756 - val_loss: 0.0762 - val_dice_coef: 0.7212 - val_accuracy: 0.9252
# Epoch 12/40
# 32/32 [==============================] - 79s 2s/step - loss: 0.0244 - dice_coef: 0.9252 - accuracy: 0.9772 - val_loss: 0.0700 - val_dice_coef: 0.7506 - val_accuracy: 0.9313
# Epoch 13/40
# 32/32 [==============================] - 79s 2s/step - loss: 0.0239 - dice_coef: 0.9269 - accuracy: 0.9775 - val_loss: 0.0450 - val_dice_coef: 0.8606 - val_accuracy: 0.9562
# Epoch 14/40
# 32/32 [==============================] - 80s 2s/step - loss: 0.0221 - dice_coef: 0.9325 - accuracy: 0.9791 - val_loss: 0.0310 - val_dice_coef: 0.9103 - val_accuracy: 0.9702
# Epoch 15/40
# 32/32 [==============================] - 78s 2s/step - loss: 0.0210 - dice_coef: 0.9361 - accuracy: 0.9800 - val_loss: 0.0268 - val_dice_coef: 0.9168 - val_accuracy: 0.9744
# Epoch 16/40
# 32/32 [==============================] - 80s 2s/step - loss: 0.0221 - dice_coef: 0.9324 - accuracy: 0.9788 - val_loss: 0.0427 - val_dice_coef: 0.8600 - val_accuracy: 0.9646
# Epoch 17/40
# 32/32 [==============================] - 79s 2s/step - loss: 0.0203 - dice_coef: 0.9381 - accuracy: 0.9805 - val_loss: 0.0342 - val_dice_coef: 0.8986 - val_accuracy: 0.9663
# Epoch 18/40
# 32/32 [==============================] - 80s 2s/step - loss: 0.0232 - dice_coef: 0.9288 - accuracy: 0.9774 - val_loss: 0.0284 - val_dice_coef: 0.9131 - val_accuracy: 0.9725
# Epoch 19/40
# 32/32 [==============================] - 79s 2s/step - loss: 0.0191 - dice_coef: 0.9415 - accuracy: 0.9815 - val_loss: 0.0250 - val_dice_coef: 0.9295 - val_accuracy: 0.9755
# Epoch 20/40
# 32/32 [==============================] - 78s 2s/step - loss: 0.0184 - dice_coef: 0.9439 - accuracy: 0.9822 - val_loss: 0.0253 - val_dice_coef: 0.9224 - val_accuracy: 0.9754
# Epoch 21/40
# 32/32 [==============================] - 79s 2s/step - loss: 0.0173 - dice_coef: 0.9471 - accuracy: 0.9832 - val_loss: 0.0197 - val_dice_coef: 0.9392 - val_accuracy: 0.9809
# Epoch 22/40
# 32/32 [==============================] - 79s 2s/step - loss: 0.0181 - dice_coef: 0.9444 - accuracy: 0.9824 - val_loss: 0.0260 - val_dice_coef: 0.9213 - val_accuracy: 0.9744
# Epoch 23/40
# 32/32 [==============================] - 79s 2s/step - loss: 0.0190 - dice_coef: 0.9419 - accuracy: 0.9814 - val_loss: 0.0258 - val_dice_coef: 0.9199 - val_accuracy: 0.9744
# Epoch 24/40
# 32/32 [==============================] - 79s 2s/step - loss: 0.0166 - dice_coef: 0.9495 - accuracy: 0.9838 - val_loss: 0.0213 - val_dice_coef: 0.9359 - val_accuracy: 0.9792
# Epoch 25/40
# 32/32 [==============================] - 80s 2s/step - loss: 0.0157 - dice_coef: 0.9523 - accuracy: 0.9847 - val_loss: 0.0198 - val_dice_coef: 0.9376 - val_accuracy: 0.9805
# Epoch 26/40
# 32/32 [==============================] - 79s 2s/step - loss: 0.0156 - dice_coef: 0.9526 - accuracy: 0.9847 - val_loss: 0.0222 - val_dice_coef: 0.9342 - val_accuracy: 0.9781
# Epoch 27/40
# 32/32 [==============================] - 78s 2s/step - loss: 0.0153 - dice_coef: 0.9535 - accuracy: 0.9851 - val_loss: 0.0211 - val_dice_coef: 0.9357 - val_accuracy: 0.9792
# Epoch 28/40
# 32/32 [==============================] - 79s 2s/step - loss: 0.0138 - dice_coef: 0.9578 - accuracy: 0.9865 - val_loss: 0.0185 - val_dice_coef: 0.9441 - val_accuracy: 0.9818
# Epoch 29/40
# 32/32 [==============================] - 78s 2s/step - loss: 0.0144 - dice_coef: 0.9559 - accuracy: 0.9859 - val_loss: 0.0326 - val_dice_coef: 0.9054 - val_accuracy: 0.9675
# Epoch 30/40
# 32/32 [==============================] - 79s 2s/step - loss: 0.0148 - dice_coef: 0.9548 - accuracy: 0.9855 - val_loss: 0.0180 - val_dice_coef: 0.9464 - val_accuracy: 0.9822
# Epoch 31/40
# 32/32 [==============================] - 78s 2s/step - loss: 0.0148 - dice_coef: 0.9551 - accuracy: 0.9854 - val_loss: 0.0191 - val_dice_coef: 0.9415 - val_accuracy: 0.9811
# Epoch 32/40
# 32/32 [==============================] - 80s 2s/step - loss: 0.0145 - dice_coef: 0.9560 - accuracy: 0.9858 - val_loss: 0.0183 - val_dice_coef: 0.9428 - val_accuracy: 0.9819
# Epoch 33/40
# 32/32 [==============================] - 78s 2s/step - loss: 0.0143 - dice_coef: 0.9565 - accuracy: 0.9859 - val_loss: 0.0211 - val_dice_coef: 0.9350 - val_accuracy: 0.9790
# Epoch 34/40
# 32/32 [==============================] - 77s 2s/step - loss: 0.0160 - dice_coef: 0.9511 - accuracy: 0.9842 - val_loss: 0.0216 - val_dice_coef: 0.9356 - val_accuracy: 0.9785
# Epoch 35/40
# 32/32 [==============================] - 79s 2s/step - loss: 0.0140 - dice_coef: 0.9575 - accuracy: 0.9862 - val_loss: 0.0207 - val_dice_coef: 0.9376 - val_accuracy: 0.9795
# Epoch 36/40
# 32/32 [==============================] - 78s 2s/step - loss: 0.0137 - dice_coef: 0.9581 - accuracy: 0.9865 - val_loss: 0.0181 - val_dice_coef: 0.9453 - val_accuracy: 0.9820
# Epoch 37/40
# 32/32 [==============================] - 80s 2s/step - loss: 0.0141 - dice_coef: 0.9572 - accuracy: 0.9861 - val_loss: 0.0212 - val_dice_coef: 0.9361 - val_accuracy: 0.9790
# Epoch 38/40
# 32/32 [==============================] - 78s 2s/step - loss: 0.0161 - dice_coef: 0.9509 - accuracy: 0.9841 - val_loss: 0.0274 - val_dice_coef: 0.9216 - val_accuracy: 0.9726
# Epoch 39/40
# 32/32 [==============================] - 79s 2s/step - loss: 0.0138 - dice_coef: 0.9580 - accuracy: 0.9863 - val_loss: 0.0192 - val_dice_coef: 0.9434 - val_accuracy: 0.9809
# Epoch 40/40
# 32/32 [==============================] - 78s 2s/step - loss: 0.0134 - dice_coef: 0.9591 - accuracy: 0.9867 - val_loss: 0.0178 - val_dice_coef: 0.9474 - val_accuracy: 0.9823

# %%
loss = results.history["loss"]
# val_loss = results.history["val_loss"]

dice_coef = results.history["dice_coef"]
# val_dice_coef = results.history["val_dice_coef"]

acc = results.history["accuracy"]
# val_acc = results.history["val_accuracy"]

# %%
plt.plot(loss,label = "loss")
# plt.plot(val_loss,label  = "val loss")
plt.xlabel("iterations")
# plt.ylabel("X axis label")
plt.legend()

# %%
plt.plot(dice_coef,label = "dice_coef")
# plt.plot(val_dice_coef,label  = "val dice_coef")
plt.xlabel("iterations")
# plt.ylabel("X axis label")
plt.legend()

# %%
plt.plot(acc,label = "acc")
# plt.plot(val_acc,label  = "val acc")
plt.xlabel("iterations")
# plt.ylabel("X axis label")
plt.legend()

# %%
def make_prediction(model,image,shape):
    img = img_to_array(load_img(image,target_size=shape))
    img = np.expand_dims(img,axis=0)/255.
    mask = model.predict(img)
    
    mask = (mask[0] > 0.5)*1
#     print(np.unique(mask,return_counts=True))
    mask = np.reshape(mask,(224,224))
    return mask

# %%
image = "/content/drive/MyDrive/COL828_Data_for_Assignment_3/train/images/seq_16_frame006.png"
img = img_to_array(load_img(image))
plt.imshow(img/255.)
img.shape
# Out:
# (1024, 1280, 3)

# %%
mask = make_prediction(model,image,(224,224,3))
mask2 = cv2.merge([mask,mask,mask]).astype('float32')
print(img.shape,mask2.shape)
mask2 = cv2.resize(mask2,(img.shape[1],img.shape[0]))
# print(mask.shape)
plt.imshow(mask2)
# Out:
# 1/1 [==============================] - 0s 60ms/step
# (1024, 1280, 3) (224, 224, 3)

# %%
h,w = img.shape[:2]
mask_resized = cv2.resize(np.uint8(mask*1),(w,h))
mask_resized = mask_resized != 0
#print(np.unique(mask_resized,return_counts=True))
segment = np.zeros((h,w,3))
segment[:,:,0] = img[:,:,0]*mask_resized
segment[:,:,1] = img[:,:,1]*mask_resized
segment[:,:,2] = img[:,:,2]*mask_resized
segment[np.where((segment == [0,0,0]).all(axis=2))] = [0,0,0]
#img[np.where((img==[255,255,255]).all(axis=2))] = [0,0,0];

# %%
plt.figure(figsize=(8,8))
plt.imshow(segment/255.)
